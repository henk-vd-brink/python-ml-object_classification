# %%
#!curl -L "https://public.roboflow.com/ds/f4QCbpT1wT?key=kumLfI87kN" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
import os
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

# %%
ANNOTATION_FILE_URI = "../data/raw/_annotations.csv"
IMAGE_FILE_URI = "../data/raw/images"
df_annotations = pd.read_csv(ANNOTATION_FILE_URI)

number_of_annotations = df_annotations.shape[0]
annotation_headers = df_annotations.columns

list_of_unique_files = df_annotations["filename"].unique()

print(
f"""Number of unique files: {len(list_of_unique_files)}
Number of annotations: {number_of_annotations}
Headers: {list(annotation_headers)}"""
)
# Out:
# Number of unique files: 718
# Number of annotations: 1934
# Headers: ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']

# %%
class Counter:
    count = 0
    
    def get_count(self):
        self.count += 1
        return self.count

counter = Counter()

def get_box_image(file_uri, filename, width, height, class_, xmin, ymin, xmax, ymax):
    img = Image.open(file_uri)
    img_width, img_height = img.size
    img_array = np.asarray(img)
    
    factor = 4
    mean_x, mean_y = int((xmin+xmax)/2), int((ymin+ymax)/2)
    range_x, range_y = int(factor*(xmax-xmin)/2), int(factor*(ymax-ymin)/2)
    
    new_img_array = img_array[mean_y-range_y: mean_y+range_y, mean_x-range_x:mean_x+range_x]
    return new_img_array
    
    #plot_image(img, mean_x, mean_y, range_x, range_y)
    
def plot_image(img, mean_x, mean_y, range_x, range_y):        
    plt.figure(figsize=(10,10))
    plt.imshow(img)
    plt.plot([mean_x-range_x, mean_x+range_x, mean_x+range_x, mean_x-range_x, mean_x-range_x], 
             [mean_y-range_y, mean_y-range_y, mean_y+range_y, mean_y+range_y, mean_y-range_y], c="k")
    plt.scatter(mean_x, mean_y, c="r")
    plt.show()

# %%
for i, file_name in enumerate(list_of_unique_files):
    file_uri = IMAGE_FILE_URI + "/" + file_name
    annotations = df_annotations[df_annotations["filename"] == file_name]

    if (number_of_annotations_in_image := len(annotations)) > 1:
        continue

    new_file_name = f"image_{counter.get_count()}.jpeg"

    new_img_array = get_box_image(file_uri, *(annotations.iloc[0].values))
    img_class = annotations.iloc[0]["class"]
    new_img = Image.fromarray(new_img_array)
    new_img.save(f"../data/semi-processed/"+new_file_name, "JPEG")

    with open("../data/semi-processed/_annotations.txt", "a") as file:
        appendix = " \n" if i != len(list_of_unique_files) else ""
        file.write(f"{new_file_name} {img_class}"+appendix)

    print(f"File: {new_file_name} added.")
# Out:
# File: image_1.jpeg added.
# File: image_2.jpeg added.
# File: image_3.jpeg added.
# File: image_4.jpeg added.
# File: image_5.jpeg added.
# File: image_6.jpeg added.
# File: image_7.jpeg added.
# File: image_8.jpeg added.
# File: image_9.jpeg added.
# File: image_10.jpeg added.
# File: image_11.jpeg added.
# File: image_12.jpeg added.
# File: image_13.jpeg added.
# File: image_14.jpeg added.
# File: image_15.jpeg added.
# File: image_16.jpeg added.
# File: image_17.jpeg added.
# File: image_18.jpeg added.
# File: image_19.jpeg added.
# File: image_20.jpeg added.
# File: image_21.jpeg added.
# File: image_22.jpeg added.
# File: image_23.jpeg added.
# File: image_24.jpeg added.
# File: image_25.jpeg added.
# File: image_26.jpeg added.
# File: image_27.jpeg added.
# File: image_28.jpeg added.
# File: image_29.jpeg added.
# File: image_30.jpeg added.
# File: image_31.jpeg added.
# File: image_32.jpeg added.
# File: image_33.jpeg added.
# File: image_34.jpeg added.
# File: image_35.jpeg added.
# File: image_36.jpeg added.
# File: image_37.jpeg added.
# File: image_38.jpeg added.
# File: image_39.jpeg added.
# File: image_40.jpeg added.
# File: image_41.jpeg added.
# File: image_42.jpeg added.
# File: image_43.jpeg added.
# File: image_171.jpeg added.
# File: image_172.jpeg added.
# File: image_173.jpeg added.
# File: image_174.jpeg added.
# File: image_175.jpeg added.
# File: image_176.jpeg added.
# File: image_177.jpeg added.
# File: image_178.jpeg added.
# File: image_179.jpeg added.
# File: image_180.jpeg added.
# File: image_181.jpeg added.
# File: image_182.jpeg added.
# File: image_183.jpeg added.
# File: image_184.jpeg added.
# File: image_185.jpeg added.
# File: image_186.jpeg added.
# File: image_187.jpeg added.
# File: image_188.jpeg added.
# File: image_189.jpeg added.
# File: image_190.jpeg added.
# File: image_191.jpeg added.
# File: image_192.jpeg added.
# File: image_193.jpeg added.
# File: image_194.jpeg added.
# File: image_195.jpeg added.
# File: image_196.jpeg added.
# File: image_197.jpeg added.
# File: image_198.jpeg added.
# File: image_199.jpeg added.
# File: image_200.jpeg added.
# File: image_201.jpeg added.
# File: image_202.jpeg added.
# File: image_203.jpeg added.
# File: image_204.jpeg added.
# File: image_205.jpeg added.
# File: image_206.jpeg added.
# File: image_207.jpeg added.
# File: image_208.jpeg added.
# File: image_209.jpeg added.
# File: image_210.jpeg added.
# File: image_211.jpeg added.
# File: image_212.jpeg added.
# File: image_213.jpeg added.
# File: image_214.jpeg added.
# File: image_215.jpeg added.
# File: image_216.jpeg added.
# File: image_217.jpeg added.
# File: image_218.jpeg added.
# File: image_219.jpeg added.
# File: image_220.jpeg added.
# File: image_221.jpeg added.
# File: image_222.jpeg added.
# File: image_223.jpeg added.
# File: image_224.jpeg added.
# File: image_225.jpeg added.
# File: image_226.jpeg added.
# File: image_227.jpeg added.
# File: image_228.jpeg added.
# File: image_229.jpeg added.
# File: image_230.jpeg added.
# File: image_231.jpeg added.
# File: image_232.jpeg added.
# File: image_233.jpeg added.
# File: image_234.jpeg added.
# File: image_235.jpeg added.
# File: image_236.jpeg added.
# File: image_237.jpeg added.
# File: image_238.jpeg added.
# File: image_239.jpeg added.
# File: image_240.jpeg added.
# File: image_241.jpeg added.
# File: image_242.jpeg added.
# File: image_243.jpeg added.
# File: image_244.jpeg added.
# File: image_245.jpeg added.
# File: image_246.jpeg added.
# File: image_247.jpeg added.
# File: image_248.jpeg added.
# File: image_249.jpeg added.
# File: image_250.jpeg added.
# File: image_251.jpeg added.
# File: image_252.jpeg added.
# File: image_253.jpeg added.
# File: image_254.jpeg added.
# File: image_255.jpeg added.
# File: image_256.jpeg added.
# File: image_257.jpeg added.
# File: image_258.jpeg added.
# File: image_259.jpeg added.
# File: image_260.jpeg added.
# File: image_261.jpeg added.
# File: image_262.jpeg added.
# File: image_263.jpeg added.
# File: image_264.jpeg added.
# File: image_265.jpeg added.
# File: image_266.jpeg added.
# File: image_267.jpeg added.
# File: image_268.jpeg added.
# File: image_269.jpeg added.
# File: image_270.jpeg added.
# File: image_271.jpeg added.
# File: image_272.jpeg added.
# File: image_273.jpeg added.
# File: image_274.jpeg added.
# File: image_275.jpeg added.
# File: image_276.jpeg added.
# File: image_277.jpeg added.
# File: image_278.jpeg added.
# File: image_279.jpeg added.
# File: image_280.jpeg added.
# File: image_281.jpeg added.
# File: image_282.jpeg added.
# File: image_283.jpeg added.
# File: image_284.jpeg added.
# File: image_285.jpeg added.
# File: image_286.jpeg added.
# File: image_287.jpeg added.
# File: image_288.jpeg added.
# File: image_289.jpeg added.
# File: image_290.jpeg added.
# File: image_291.jpeg added.
# File: image_292.jpeg added.
# File: image_293.jpeg added.
# File: image_294.jpeg added.
# File: image_295.jpeg added.
# File: image_296.jpeg added.
